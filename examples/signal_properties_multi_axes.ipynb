# %%
# Loads the autoreload extension in Notebook
# %load_ext autoreload
# Sets the autoreload mode to reload all modules before executing code
# %autoreload 2

# %%
from caits.properties import sma_signal, magnitude_signal
from caits.visualization import plot_signal
from utils import *

# %%
motion = load_csv_instance()

# %%
motion["signal"].shape
# Out:
# (1034, 6)

# %% [markdown]
# # Simple Moving Average (SMA)

# %%
sma = sma_signal(motion["signal"])

# %%
plot_signal(sma, title="SMA Signal", return_mode=False)

# %% [markdown]
# # Magnitude

# %%
magnitude = magnitude_signal(motion["signal"])

# %%
plot_signal(magnitude, title="Magnitude Signal", return_mode=False)
