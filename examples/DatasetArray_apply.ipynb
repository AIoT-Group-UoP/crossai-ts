# %%
import pandas as pd
from caits.dataset import CoreArray, DatasetArray

# %%
init_data = pd.read_csv("data/AirQuality.csv", sep=";", decimal=",")
print(init_data)
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
init_data["Datetime"] = init_data["Date"] + " " + init_data["Time"]
init_data = init_data.drop(columns=["Date", "Time"]).set_index("Datetime")
init_data = init_data[init_data.index.isna() == False]
print(init_data)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Datetime
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0
# ...                     ...          ...       ...       ...            ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0
# 04/04/2005 14.00.00     2.2       1071.0    -200.0      11.9         1047.0
#
# ...

# %%
X_df = init_data.iloc[:, :-5]
X_values = X_df.values
X_axis_names = {
    "axis_0": X_df.index.values,
    "axis_1": X_df.columns
}

X = CoreArray(X_values, X_axis_names)
print(X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
y_df = init_data.iloc[:, -5:-2]
y_values = y_df.values
y_axis_names = {
    "axis_0": y_df.index.values,
    "axis_1": y_df.columns
}

y = CoreArray(y_values, y_axis_names)
print(y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)

# %%
data = DatasetArray(X, y)
print(data)
# Out:
# DatasetArray object with 9357 instances.

# %% [markdown]
# # Test default arguments:
# - to_X = True
# - to_y = False
# - dataset
# - axis_names_X = None
# - axis_names_y = None

# %%
from caits.filtering import filter_butterworth

tr_data = data.apply(filter_butterworth, fs=1000, cutoff_freq=50)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# ...

# %% [markdown]
# # Test default arguments:
# - to_X = True
# - to_y = True
# - datasetList = False
# - axis_names_X = None
# - axis_names_y = None

# %%
tr_data = data.apply(filter_butterworth, fs=1000, cutoff_freq=50, to_y=True)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       T                  RH                  AH
# 10/03/2004 18.00.00   13.67346451976196  48.782502824611086  0.7594457001759646
# 10/03/2004 19.00.00  13.176960115282553  50.449783340821895  0.7591877642125542
# ...

# %% [markdown]
# # Test default arguments:
# - to_X = False
# - to_y = True
# - datasetList = False
# - axis_names_X = None
# - axis_names_y = None

# %%
tr_data = data.apply(filter_butterworth, fs=1000, cutoff_freq=50, to_X=False, to_y=True)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       T                  RH                  AH
# 10/03/2004 18.00.00   13.67346451976196  48.782502824611086  0.7594457001759646
# 10/03/2004 19.00.00  13.176960115282553  50.449783340821895  0.7591877642125542
# ...

# %%
tr_data = data.apply(filter_butterworth, fs=1000, cutoff_freq=50, to_X=False, to_y=False)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# ...

# %%
axis_names_X = {"axis_1": data.X.keys()["axis_1"]}
axis_names_y = {"axis_1": data.y.keys()["axis_1"]}

# %%
tr_data = data.apply(filter_butterworth, fs=1000, cutoff_freq=50, to_X=True, to_y=True, axis_names_X=axis_names_X)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       T                  RH                  AH
# 10/03/2004 18.00.00   13.67346451976196  48.782502824611086  0.7594457001759646
# 10/03/2004 19.00.00  13.176960115282553  50.449783340821895  0.7591877642125542
# ...

# %%
tr_data = data.apply(
    filter_butterworth,
    fs=1000,
    cutoff_freq=50,
    to_X=True,
    to_y=True,
    axis_names_X=axis_names_X,
    axis_names_y=axis_names_y
)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                        T                  RH                  AH
#    0   13.67346451976196  48.782502824611086  0.7594457001759646
#    1  13.176960115282553  50.449783340821895  0.7591877642125542
#    2  12.687573964920102  52.052099957255244  0.7584500972645221
# ...

# %%
tr_data = data.apply(
    filter_butterworth,
    fs=1000,
    cutoff_freq=50,
    to_X=True,
    to_y=False,
    axis_names_X=axis_names_X,
    axis_names_y=axis_names_y
)
print(tr_data)
# Out:
# DatasetArray object with 9357 instances.

# %%
print(data.X)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.X)
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 10/03/2004 18.00.00     2.6       1360.0     150.0      11.9         1046.0    166.0
# 10/03/2004 19.00.00     2.0       1292.0     112.0       9.4          955.0    103.0
# 10/03/2004 20.00.00     2.2       1402.0      88.0       9.0          939.0    131.0
# 10/03/2004 21.00.00     2.2       1376.0      80.0       9.2          948.0    172.0
# 10/03/2004 22.00.00     1.6       1272.0      51.0       6.5          836.0    131.0
#                 ...     ...          ...       ...       ...            ...      ...
# 04/04/2005 10.00.00     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 04/04/2005 11.00.00     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 04/04/2005 12.00.00     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 04/04/2005 13.00.00     2.1       1003.0    -200.0       9.5          961.0    235.0
# ...

# %%
print(data.y)
print("------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(tr_data.y)
# Out:
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# 04/04/2005 10.00.00  21.9  29.3  0.7568
# 04/04/2005 11.00.00  24.3  23.7  0.7119
# 04/04/2005 12.00.00  26.9  18.3  0.6406
# 04/04/2005 13.00.00  28.3  13.5  0.5139
# 04/04/2005 14.00.00  28.5  13.1  0.5028
#
# CoreArray with shape (9357, 3)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#                         T    RH      AH
# 10/03/2004 18.00.00  13.6  48.9  0.7578
# 10/03/2004 19.00.00  13.3  47.7  0.7255
# 10/03/2004 20.00.00  11.9  54.0  0.7502
# 10/03/2004 21.00.00  11.0  60.0  0.7867
# 10/03/2004 22.00.00  11.2  59.6  0.7888
#                 ...   ...   ...     ...
# ...
