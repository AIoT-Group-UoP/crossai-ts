# %% [markdown]
# # Air Quality Dataset
#
# From the Kaggle Dataset containing sensor measuremenats for Air Quality, we extract correlation
# measurements. We perform filtering on these signals (simultaneously), we extract correlation
# and extraxt features and signal properties out of these

# %% [markdown]
# ## Step 1: Initialization

# %%
import pandas as pd
from caits import visualization, filtering, properties
from caits.fe import signal_stats
from caits.eda import correlation
import seaborn as sns

# %%
data = pd.read_csv(
    "data/AirQuality.csv",
    sep=";").drop(
    columns=[
        "Date",
        "Time",
        "Unnamed: 15",
        "Unnamed: 16"
    ]
)

data = data.apply(lambda col: col.str.replace(",", ".").astype(float) if col.dtypes == "object" else col)
data = data.fillna(0)

# %%
data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1     2.0       1292.0     112.0       9.4          955.0    103.0
# 2     2.2       1402.0      88.0       9.0          939.0    131.0
# 3     2.2       1376.0      80.0       9.2          948.0    172.0
# 4     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888

# %% [markdown]
# ### Plot the Air Quality Measurements

# %%
init_fig = visualization.plot_signal(
    data.values,
    channels=data.columns.tolist(),
    title="Air Quality Measurements"
)

# %% [markdown]
# ### Print various statistics of the signals

# %%
stats = [
    signal_stats(data[col].values, col)
    for col in data.columns
]

for s in stats:
    for k, v in s.items():
        print(f"{k}: {v}")
    print("---------------------------------------")
# Out:
# CO(GT)_max: 11.9
# CO(GT)_min: -200.0
# CO(GT)_mean: -33.79577658114244
# CO(GT)_median: 1.5
# CO(GT)_std: 77.2743518484747
# CO(GT)_var: 5971.325453601864
# CO(GT)_kurtosis: 0.841677463171774
# CO(GT)_skewness: -1.685382763668135
# CO(GT)_rms: 84.34144869709293
# CO(GT)_crest_factor: 2.3713133114216185
# CO(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S1(CO)_max: 2040.0
# PT08.S1(CO)_min: -200.0
# PT08.S1(CO)_mean: 1036.3636363636363
# PT08.S1(CO)_median: 1050.0
# PT08.S1(CO)_std: 347.2091940549927
# PT08.S1(CO)_var: 120554.22443631756
# PT08.S1(CO)_kurtosis: 4.855653476724188
# PT08.S1(CO)_skewness: -1.6805821235311562
# PT08.S1(CO)_rms: 1092.979327898372
# PT08.S1(CO)_crest_factor: 1.8664579904933796
# PT08.S1(CO)_signal_length: 0.21476190476190476
# ---------------------------------------
# NMHC(GT)_max: 1189.0
# NMHC(GT)_min: -200.0
# NMHC(GT)_mean: -157.17516629711753
# NMHC(GT)_median: -200.0
# NMHC(GT)_std: 140.01677139806938
# NMHC(GT)_var: 19604.696272739217
# NMHC(GT)_kurtosis: 18.246469389822106
# NMHC(GT)_skewness: 3.9830845330200266
# NMHC(GT)_rms: 210.49638755395722
# NMHC(GT)_crest_factor: 5.648552993315478
# NMHC(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# C6H6(GT)_max: 63.7
# C6H6(GT)_min: -200.0
# C6H6(GT)_mean: 1.8432266920071796
# C6H6(GT)_median: 7.8
# C6H6(GT)_std: 41.12871632336979
# C6H6(GT)_var: 1691.5713064082242
# C6H6(GT)_kurtosis: 19.436955668953885
# C6H6(GT)_skewness: -4.534333320184578
# C6H6(GT)_rms: 41.169998676783464
# C6H6(GT)_crest_factor: 4.857906398544136
# C6H6(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S2(NMHC)_max: 2214.0
# PT08.S2(NMHC)_min: -200.0
# PT08.S2(NMHC)_mean: 883.8272621687256
# PT08.S2(NMHC)_median: 890.0
# PT08.S2(NMHC)_std: 353.9578154048135
# PT08.S2(NMHC)_var: 125286.13508614803
# PT08.S2(NMHC)_kurtosis: 2.0262238575983567
# PT08.S2(NMHC)_skewness: -0.8120961489223428
# PT08.S2(NMHC)_rms: 952.069726668595
# PT08.S2(NMHC)_crest_factor: 2.325459930069459
# PT08.S2(NMHC)_signal_length: 0.21476190476190476
# ---------------------------------------
# NOx(GT)_max: 1479.0
# NOx(GT)_min: -200.0
# NOx(GT)_mean: 166.58737197761587
# NOx(GT)_median: 139.0
# NOx(GT)_std: 256.52602656847444
# NOx(GT)_var: 65805.60230700966
# NOx(GT)_kurtosis: 1.5407024548918713
# NOx(GT)_skewness: 0.8441729888698327
# NOx(GT)_rms: 305.8708139221822
# NOx(GT)_crest_factor: 4.835374715994571
# NOx(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S3(NOx)_max: 2683.0
# PT08.S3(NOx)_min: -200.0
# PT08.S3(NOx)_mean: 785.4210748600992
# PT08.S3(NOx)_median: 791.0
# PT08.S3(NOx)_std: 331.56703649320747
# PT08.S3(NOx)_var: 109936.69968888798
# PT08.S3(NOx)_kurtosis: 2.7046610516455027
# PT08.S3(NOx)_skewness: -0.4274075687145668
# PT08.S3(NOx)_rms: 852.539127854717
# PT08.S3(NOx)_crest_factor: 3.147069632746775
# PT08.S3(NOx)_signal_length: 0.21476190476190476
# ---------------------------------------
# NO2(GT)_max: 340.0
# NO2(GT)_min: -200.0
# NO2(GT)_mean: 57.44894942455918
# NO2(GT)_median: 95.0
# NO2(GT)_std: 126.32667572943421
# NO2(GT)_var: 15958.429000849625
# NO2(GT)_kurtosis: 0.27150448472942923
# NO2(GT)_skewness: -1.2129629614320663
# NO2(GT)_rms: 138.77611750886814
# NO2(GT)_crest_factor: 2.4499892784381516
# NO2(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S4(NO2)_max: 2775.0
# PT08.S4(NO2)_min: -200.0
# PT08.S4(NO2)_mean: 1374.7307570478301
# PT08.S4(NO2)_median: 1440.0
# PT08.S4(NO2)_std: 488.5284170849125
# PT08.S4(NO2)_var: 238660.01429949023
# PT08.S4(NO2)_kurtosis: 2.7902294178666027
# PT08.S4(NO2)_skewness: -1.2502486161414466
# PT08.S4(NO2)_rms: 1458.953278440674
# PT08.S4(NO2)_crest_factor: 1.9020485720871843
# PT08.S4(NO2)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S5(O3)_max: 2523.0
# PT08.S5(O3)_min: -200.0
# PT08.S5(O3)_mean: 963.3353394572907
# PT08.S5(O3)_median: 936.0
# PT08.S5(O3)_std: 466.4371848878328
# PT08.S5(O3)_var: 217563.6474460863
# PT08.S5(O3)_kurtosis: 0.5282812205669787
# PT08.S5(O3)_skewness: -0.06665305867579087
# PT08.S5(O3)_rms: 1070.3170668981131
# PT08.S5(O3)_crest_factor: 2.3572454163623764
# PT08.S5(O3)_signal_length: 0.21476190476190476
# ---------------------------------------
# T_max: 44.6
# T_min: -200.0
# T_mean: 9.660606060606062
# T_median: 17.0
# T_std: 42.95376336671397
# T_var: 1845.025787363659
# T_kurtosis: 18.953259970426785
# T_skewness: -4.460243401105191
# T_rms: 44.02673161639275
# T_crest_factor: 4.542694691548094
# T_signal_length: 0.21476190476190476
# ---------------------------------------
# RH_max: 88.7
# RH_min: -200.0
# RH_mean: 39.01010452961673
# RH_median: 48.1
# RH_std: 51.086040988584045
# RH_var: 2609.7835838872893
# RH_kurtosis: 15.573790366460877
# RH_skewness: -3.8918408675354037
# RH_rms: 64.27730423173418
# RH_crest_factor: 3.1115181694452354
# RH_signal_length: 0.21476190476190476
# ---------------------------------------
# AH_max: 2.231
# AH_min: -200.0
# AH_mean: -6.755301161440185
# AH_median: 0.9711
# AH_std: 38.74648889501748
# AH_var: 1501.2904016917128
# AH_kurtosis: 20.911944163185304
# AH_skewness: -4.787087057912851
# AH_rms: 39.33096102911124
# AH_crest_factor: 5.085052456561328
# AH_signal_length: 0.21476190476190476
# ---------------------------------------

# %% [markdown]
# ### Correlations

# %%
signal_correlations = data.corr()

fig = sns.heatmap(signal_correlations, annot=False, cmap="coolwarm", vmin=-1, vmax=1)

# %%
highly_corr_features = correlation.get_high_corr_features(data, 0.9)
highly_corr_data = data[highly_corr_features]
highly_corr_data.head()
# Out:
#    PT08.S2(NMHC)  PT08.S5(O3)     T    RH      AH
# 0         1046.0       1268.0  13.6  48.9  0.7578
# 1          955.0        972.0  13.3  47.7  0.7255
# 2          939.0       1074.0  11.9  54.0  0.7502
# 3          948.0       1203.0  11.0  60.0  0.7867
# 4          836.0       1110.0  11.2  59.6  0.7888

# %%
signal_correlations = highly_corr_data.corr()

fig = sns.heatmap(signal_correlations, annot=False, cmap="coolwarm", vmin=-1, vmax=1)

# %% [markdown]
# ## Step 2: Filtering
#
# We perform a Gaussian Filter on all timeseries simultaneously

# %%
filtered_data = filtering.filter_gaussian(data.values)

# %%
filtered_fig = visualization.plot_signal(
    filtered_data,
    channels = data.columns.tolist(),
    title="Filtered Air Quality Measurements"
)

# %% [markdown]
# ### Print various statistics of the signals

# %%
filtered_data_df = pd.DataFrame(filtered_data, columns=data.columns)

stats = [
    signal_stats(filtered_data_df[col].values, col)
    for col in filtered_data_df.columns
]

for s in stats:
    for k, v in s.items():
        print(f"{k}: {v}")
    print("---------------------------------------")
# Out:
# CO(GT)_max: 602.7834934887135
# CO(GT)_min: -200.0
# CO(GT)_mean: 276.0086869289514
# CO(GT)_median: 288.99840453697425
# CO(GT)_std: 111.52869169043908
# CO(GT)_var: 12438.649070181013
# CO(GT)_kurtosis: 2.375657331504633
# CO(GT)_skewness: -1.147856589689986
# CO(GT)_rms: 297.6901817837212
# CO(GT)_crest_factor: 2.0248685726781868
# CO(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S1(CO)_max: 965.1122070868987
# PT08.S1(CO)_min: -200.0
# PT08.S1(CO)_mean: 374.0271152739772
# PT08.S1(CO)_median: 376.6593860458845
# PT08.S1(CO)_std: 147.32674694887723
# PT08.S1(CO)_var: 21705.170366538503
# PT08.S1(CO)_kurtosis: 4.076889307292731
# PT08.S1(CO)_skewness: -1.183322714302582
# PT08.S1(CO)_rms: 401.9968324834308
# PT08.S1(CO)_crest_factor: 2.400795551359669
# PT08.S1(CO)_signal_length: 0.21476190476190476
# ---------------------------------------
# NMHC(GT)_max: 911.7353302776623
# NMHC(GT)_min: -200.0
# NMHC(GT)_mean: 235.2388922158718
# NMHC(GT)_median: 231.03401229625726
# NMHC(GT)_std: 123.84547039276791
# NMHC(GT)_var: 15337.700536805953
# NMHC(GT)_kurtosis: 4.815305112583789
# NMHC(GT)_skewness: -0.4323402352138326
# NMHC(GT)_rms: 265.8477702516169
# NMHC(GT)_crest_factor: 3.4295391284069536
# NMHC(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# C6H6(GT)_max: 730.0201831679639
# C6H6(GT)_min: -200.0
# C6H6(GT)_mean: 244.8473473819712
# C6H6(GT)_median: 244.8607167964667
# C6H6(GT)_std: 121.35080151223417
# C6H6(GT)_var: 14726.017027661655
# C6H6(GT)_kurtosis: 3.3985850104368005
# C6H6(GT)_skewness: -0.9245713727932451
# C6H6(GT)_rms: 273.2695382724707
# C6H6(GT)_crest_factor: 2.6714290505371943
# C6H6(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S2(NMHC)_max: 1124.393238061425
# PT08.S2(NMHC)_min: -200.0
# PT08.S2(NMHC)_mean: 432.29929881921385
# PT08.S2(NMHC)_median: 429.0322928418198
# PT08.S2(NMHC)_std: 169.3910604597092
# PT08.S2(NMHC)_var: 28693.331363664856
# PT08.S2(NMHC)_kurtosis: 2.2887599184528993
# PT08.S2(NMHC)_skewness: -0.6481240971911054
# PT08.S2(NMHC)_rms: 464.3016423869819
# PT08.S2(NMHC)_crest_factor: 2.421686971170083
# PT08.S2(NMHC)_signal_length: 0.21476190476190476
# ---------------------------------------
# NOx(GT)_max: 1110.9106605400668
# NOx(GT)_min: -200.0
# NOx(GT)_mean: 479.2342876900448
# NOx(GT)_median: 491.69205143504394
# NOx(GT)_std: 152.62727288750736
# NOx(GT)_var: 23295.08442907764
# NOx(GT)_kurtosis: 4.054050400812664
# NOx(GT)_skewness: -1.1245106031768142
# NOx(GT)_rms: 502.951873370467
# NOx(GT)_crest_factor: 2.2087812360563297
# NOx(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S3(NOx)_max: 1151.4249491640855
# PT08.S3(NOx)_min: -200.0
# PT08.S3(NOx)_mean: 493.74889075998703
# PT08.S3(NOx)_median: 523.8451165234367
# PT08.S3(NOx)_std: 141.8148585255726
# PT08.S3(NOx)_var: 20111.454098628165
# PT08.S3(NOx)_kurtosis: 6.550369107378998
# PT08.S3(NOx)_skewness: -2.0901962129811418
# PT08.S3(NOx)_rms: 513.7114182353218
# PT08.S3(NOx)_crest_factor: 2.2413847703043244
# PT08.S3(NOx)_signal_length: 0.21476190476190476
# ---------------------------------------
# NO2(GT)_max: 968.947301931649
# NO2(GT)_min: -200.0
# NO2(GT)_mean: 610.5850279054466
# NO2(GT)_median: 641.3749914029759
# NO2(GT)_std: 171.06670546076106
# NO2(GT)_var: 29263.81771719878
# NO2(GT)_kurtosis: 7.724458024338343
# NO2(GT)_skewness: -2.553132847191446
# NO2(GT)_rms: 634.0961236433274
# NO2(GT)_crest_factor: 1.5280763685549228
# NO2(GT)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S4(NO2)_max: 1618.4800672166118
# PT08.S4(NO2)_min: -200.0
# PT08.S4(NO2)_mean: 839.3964227296215
# PT08.S4(NO2)_median: 860.1737733192318
# PT08.S4(NO2)_std: 283.68038624476446
# PT08.S4(NO2)_var: 80474.56153997876
# PT08.S4(NO2)_kurtosis: 3.4418596232479555
# PT08.S4(NO2)_skewness: -1.4154254353791884
# PT08.S4(NO2)_rms: 886.036633571809
# PT08.S4(NO2)_crest_factor: 1.8266514113442034
# PT08.S4(NO2)_signal_length: 0.21476190476190476
# ---------------------------------------
# PT08.S5(O3)_max: 1535.0878724401532
# PT08.S5(O3)_min: -200.0
# PT08.S5(O3)_mean: 727.9797844183644
# PT08.S5(O3)_median: 739.5770802477153
# PT08.S5(O3)_std: 280.1351076660395
# PT08.S5(O3)_var: 78475.67854706355
# PT08.S5(O3)_kurtosis: 2.4906109842550412
# PT08.S5(O3)_skewness: -1.0630674826928417
# PT08.S5(O3)_rms: 780.0193876237129
# PT08.S5(O3)_crest_factor: 1.9680124581476313
# PT08.S5(O3)_signal_length: 0.21476190476190476
# ---------------------------------------
# T_max: 713.6857450072291
# T_min: -200.0
# T_mean: 320.5865503476846
# T_median: 327.31339023093676
# T_std: 146.62922181402402
# T_var: 21500.12868978626
# T_kurtosis: 3.6831701163667265
# T_skewness: -1.3422620775109877
# T_rms: 352.52782153131517
# T_crest_factor: 2.0244806265420734
# T_signal_length: 0.21476190476190476
# ---------------------------------------
# RH_max: 168.49135638978345
# RH_min: -200.0
# RH_mean: 74.18714718207049
# RH_median: 82.87448850298905
# RH_std: 58.711843063175486
# RH_var: 3447.0805158749477
# RH_kurtosis: 14.043653011218808
# RH_skewness: -3.578360592888053
# RH_rms: 94.60873808950808
# RH_crest_factor: 2.113969640000722
# RH_signal_length: 0.21476190476190476
# ---------------------------------------
# AH_max: 34.384585551849305
# AH_min: -200.0
# AH_mean: 12.362632889082425
# AH_median: 20.817826301029207
# AH_std: 41.99470795179201
# AH_var: 1763.555495956303
# AH_kurtosis: 20.28697234612367
# AH_skewness: -4.649970091773311
# AH_rms: 43.776594064711404
# AH_crest_factor: 4.568651451146614
# AH_signal_length: 0.21476190476190476
# ---------------------------------------

# %% [markdown]
# ### Correlations

# %%
signal_correlations = filtered_data_df.corr()

fig = sns.heatmap(signal_correlations, annot=False, cmap="coolwarm", vmin=-1, vmax=1)

# %%
highly_corr_filtered_data_columns = correlation.get_high_corr_features(filtered_data_df, 0.9)

highly_corr_filtered_data = filtered_data_df[list(highly_corr_filtered_data_columns)]
highly_corr_filtered_data.head()
# Out:
#    PT08.S1(CO)    NMHC(GT)    C6H6(GT)  PT08.S2(NMHC)     NOx(GT)  \
# 0   579.930382  437.021021  367.160737     514.785560  582.724787
# 1   575.306406  427.290850  353.042898     497.939277  575.951781
# 2   575.966976  420.260656  340.612740     485.170832  571.946417
# 3   564.425882  406.519414  326.264877     471.595870  569.315495
# 4   534.792415  380.206010  300.837518     442.578942  562.586219
#
#    PT08.S4(NO2)  PT08.S5(O3)           T         RH         AH
# 0   1025.468552   880.624119  389.417482  93.591043  21.289430
# 1    991.146818   841.102245  369.826151  89.983562  21.342617
# 2    979.277890   832.091428  367.680215  90.893365  22.359441
# 3    978.085494   837.638983  373.788403  93.645554  23.559908
# 4    944.747235   802.776377  358.236504  91.083795  23.725046

# %%
signal_correlations = highly_corr_filtered_data.corr()

fig = sns.heatmap(signal_correlations, annot=False, cmap="coolwarm", vmin=-1, vmax=1)

# %% [markdown]
# ## Step 3: Properties Extraction

# %% [markdown]
# ### SMA (Simple Moving Average)

# %%
sma = properties.sma_signal(highly_corr_filtered_data.values)

fig = visualization.plot_signal(
    sma,
    title="Simple Moving Average of filtered Air Quality Measurements",
    channels=["Sma"]
)

# %% [markdown]
# ### Magnitude

# %%
mag = properties.magnitude_signal(highly_corr_filtered_data.values)

fig = visualization.plot_signal(
    mag,
    title="Magnitude of filtered Air Quality Measurements",
    channels=["Magnitude"]
)

# %% [markdown]
# ### Rolling RMS

# %%
roll_rms = properties.rolling_rms(
    highly_corr_filtered_data.values,
    50,
    20
)

fig = visualization.plot_signal(
    roll_rms,
    title="Rolling RMS of filtered Air Quality Measurements",
    channels=["RMS"]
)

# %% [markdown]
# ### Rolling Zero Crossing Rate

# %%
roll_zcr = properties.rolling_zcr(highly_corr_filtered_data.values.T)  # Transpose to have channels as rows (inverse matrix)

fig = visualization.plot_signal(
    roll_zcr.T,  # Transpose back to have channels as columns
    title="Rolling ZCR of filtered Air Quality Measurements",
    channels=["ZCR"]
)
