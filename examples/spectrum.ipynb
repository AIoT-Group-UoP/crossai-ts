# %%
# Loads the autoreload extension in Notebook
# %load_ext autoreload
# Sets the autoreload mode to reload all modules before executing code
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from caits.loading import wav_specs_check
from caits.visualization import plot_signal
from caits.fe import stft, power_to_db, spectrogram, melspectrogram, pcen
from utils import load_wav_instance
from IPython.display import Audio

# %%
audio = load_wav_instance(path="data/yes.wav", return_vector=True)
# Out:
# 1

# %%
# Load audio file
y = audio["signal"]
sr = audio["sr"]

# %%
audio_params = wav_specs_check("data/yes.wav")
audio_params
# Out:
# {'nchannels': 1,
#  'sampwidth': 2,
#  'framerate': 16000,
#  'nframes': 16000,
#  'comptype': 'NONE',
#  'compname': 'not compressed'}

# %%
plot_signal(y, sr, return_mode=False)

# %% [markdown]
# # Definitions

# %%
FRAME_SIZE = 2048
HOP_LENGTH = 128
N_MELS = 128
LOWER_FREQ = 80
UPPER_FREQ = 1000

# %% [markdown]
# # Spectrogram

# %%
# Compute the short-time Fourier transform (STFT) of the audio signal
D = stft(y)

# %%
S_db = power_to_db(np.abs(D), ref=np.max)

# %%
import librosa

# %%
# Plot the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, x_axis='time', y_axis='log', sr=sr)
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.tight_layout()
plt.show()
